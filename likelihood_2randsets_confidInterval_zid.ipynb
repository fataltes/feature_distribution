# %% [markdown]
# # Database Initialization

# %%
from __future__ import division
db = 'twitterGender'
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
myDB = URL(drivername='mysql', database=db, query={ 'read_default_file' : '/home/fatal/.my.cnf' })
engine = create_engine(name_or_url=myDB, encoding='utf8')
#conn = engine.connect()

# %% [markdown]
# # Necessary Libraries & Global Variables

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy
import scipy.stats as ss
import pandas as pd
import warnings
import random

import time
import pdb

epsilon = 0.0000001
SMALL_VAL = 1
Zero = 0
RAND_COUNT = 10000
group_id_cnt = 0

# %% [markdown]
# # Find Best Fit Distribution
# ## Function name: best_fit_distribution
# **Args:**
# * data -> a series of data values (like group norms in our case)
# * bins -> how many bins we want to divide the data into (default = 200)
# * ax -> axes subplots (default None)
#   * subplot of the data with x and y limits set
#   * If given, this function will add histogram of data + all different distribution lines to this subplot
#
# **Returns:**
# * Best_Distribution_name -> winner among all distributions
# * Best_SSE -> Minimum sum of squared error
# * Best_params -> parameters of the best distribution which has at least two parameters of "Location" and "Scale" + any additional parameters based on the distribution type
#
# **What it does?**
# * Creates a histogram of the data divided to <BINS> bins
# * Sets x as the center of each bin
# * Sets y as the frequency value of each bin (normed = True)
# * Finds the best fit distribution among previously defined distributions based on the SSE of the returned value and the actual value
#   * Uses scipy.stats distribution methods **fit** and **pdf**
#   * scipy.stats current Distributions are **norm**, **expon**, and **lognorm** for now
# * If ax is set, it adds histogram and all the distributions lines with their MLE parameters to that

# %%
# Create models from data
def best_fit_distribution(input_data, ax=None, plot_pdf = False, test_significance=True):
    """Model data by finding best fit distribution to data"""
    DISTRIBUTIONS = [
        #ss.norm, ss.lognorm, ss.expon, ss.powerlaw
        ss.norm, ss.lognorm, ss.powerlaw, ss.fisk
    ]
    """Zero_Inflated distributions"""
    ZI_DISTRIBUTIONS = [
        ss.lognorm, ss.powerlaw
        # ss.norm if you want to add this you have to change p0 because the probablity should also include 
        # probability of 0 comming from normal distribution.
        # closed form p0 for normal is : (N*f0-N0)/(N*f0-N)
    ]
    # Best holders
    best_distribution = ss.norm
    best_params = (0.0, 1.0)
    best_ll = -1 * np.inf
    significant = True

    dist_ll = {}

    N = len(input_data)
    random.shuffle(input_data)
    train_end = int(N/2)
    #data = np.sort(input_data[0:train_end])
    #test = np.sort(input_data[train_end:N])
    data = np.sort(input_data)
    test = np.sort(input_data)
    input_data = np.sort(input_data)

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')
                
                
                # fit dist to data
                params = distribution.fit(data)
                
                ll = np.sum(distribution.logpdf(test, loc=params[-2], scale=params[-1], *params[:-2]))
                dist_ll[distribution.name] = [round(ll, 2), params]
                # if axis pass in add to plot
                try:
                    if ax:
                        # Calculate fitted PDF and error with fit in distribution
                        if plot_pdf:
                            y = distribution.pdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        else:
                            y = distribution.cdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        pd.Series(y, input_data). \
                        plot(ax=ax, label=distribution.name + str(round(ll, 2)))
                except Exception as detail:
                    print('Plotting Runtime Error: ' + str(detail))
                    pass
                # identify if this distribution is better
                if best_ll < ll:
                    best_distribution = distribution
                    best_params = params
                    best_ll = ll

        except Exception as detail:
            print('Runtime Error: ' + str(detail))
            pass

    # Estimate zero_inflated distribution parameters from data
    noZero_input_data = [el for el in input_data if el != 0]
    noZero_data = [el for el in data if el != 0]
    ctot = len(data)
    c0 = ctot - len(noZero_data)
    p0 = c0/ctot
    noZero_test = [el for el in test if el != 0]
    test_ctot = len(test)
    test_c0 = test_ctot - len(noZero_test)
    for zi_distribution in ZI_DISTRIBUTIONS:
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')
                
                
                # fit dist to data
                params = zi_distribution.fit(noZero_data)
                
                p1 = 1 - p0
                # divide probability by scale to generate a pdf val at x = 0 and x != 0
                # TODO not sure about p1 if it needs division by scale??????????
                p0 = p0 / params[-1]
                p1 = p1 / params[-1]
                
                ll = np.sum(zi_distribution.logpdf(noZero_test, loc=params[-2], scale=params[-1], *params[:-2]))
                if ll == float("-inf"):
                    pdb.set_trace()
                # Added for zero_inflated part. You should sum log likelihood for zeros and also 
                # consider ll as the log likelihood for nonzeros that each will happen with probability (1 - p0)
                # Be careful that p0 is calculated from train data.
                if p0 != 0:
                    ll += test_c0*np.log(p0) + (test_ctot-test_c0)*np.log(p1)
                dist_ll["zi_"+zi_distribution.name] = [round(ll, 2), params, p0]
                # if axis pass in add to plot
                try:
                    if ax:
                        #pdb.set_trace()
                        # Calculate fitted PDF and error with fit in distribution
                        if plot_pdf:
                            y = zi_distribution.pdf(noZero_input_data, loc=params[-2], \
                                                    scale=params[-1], *params[:-2])
                        else:
                            y = zi_distribution.cdf(noZero_input_data, loc=params[-2], \
                                                 scale=params[-1], *params[:-2])
                        y = [p0] + y.tolist()
                        pd.Series(y, [0] + noZero_input_data). \
                        plot(ax=ax, label="zi_"+zi_distribution.name + str(round(ll, 2)))
                except Exception as detail:
                    print('Plotting Runtime Error: ' + str(detail))
                    pass
                # identify if this distribution is better
                if best_ll < ll:
                    best_distribution = zi_distribution
                    best_params = params
                    best_ll = ll

        except Exception as detail:
            print('Runtime Error: ' + str(detail))
            pass
    return (best_distribution.name, best_ll, best_params, dist_ll)

# %% [markdown]
# # Distribution of best fit distributions among all different features
#
#  Gives you count of features in each distribution
#  And also best fitted distribution to each feature

# %%
def fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random=True):
    if use_random and group_id_cnt > RAND_COUNT:
        fetch_data_query = "select * from {0} join \
        (select ceil(rand()*{3}) as id from {0} where feat='{1}') as r2 using(id) limit {2}" \
        .format(table_name, feat, feat_needed_cnt, feat_total_cnt)
    else:
        fetch_data_query = "select * from {0} where feat = '{1}'" \
        .format(table_name, feat)
    raw_df = pd.read_sql(fetch_data_query, con=engine)
    return raw_df
    
    
def prepare_data(table_name, feat, feat_total_cnt, feat_needed_cnt, include_zero=True, use_random=True):
    raw_df = fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random)
    data = raw_df.group_norm.tolist()
    total_cnt = group_id_cnt
    if use_random and total_cnt > RAND_COUNT:
        total_cnt = RAND_COUNT
    nonExisting_cnt = max(0, int(total_cnt - len(data)))
    # Appending zero for those that does not use this feature at all
    # By removing this line you can find the best 
    if include_zero:
        data = data + ([Zero]*nonExisting_cnt)
    return np.sort(data).tolist()

def find_best_fit_for_all_feats(table_name, include_zero=True, use_random=True, \
                                confidence=False):
    pval_threshold = 0.05
    cntr = 1
    usr_best_fit = []
    query_time = 0
    fit_time = 0

    # Load DATA from DB
    stime = time.time()
    global group_id_cnt
    #pdb.set_trace()
    group_id_cnt = pd.read_sql('select count(distinct group_id) cnt from ' + table_name, con=engine)
    group_id_cnt = group_id_cnt.cnt[0]
    print(str(group_id_cnt) + ' data points for each feature')
    print(str(RAND_COUNT) + ' random data points will be selected instead, if it is smaller')
    # Load distinct features
    features = pd.read_sql('select feat, count(*) cnt from ' + table_name + ' group by feat', con=engine)
    feat_cnt = len(features)
    print(str(feat_cnt) + ' unique features' )
        
    if include_zero:
        rand_proportion = min(RAND_COUNT/group_id_cnt, 1)
    else:
        rand_proportion = 1
    # Load data feature by feature and find the best distribution for each feature
    for index, eachfeat in (features.iloc[0:1]).iterrows():
        feat = eachfeat.feat
        feat = feat.replace("'", "''").replace("%", "%%").replace('\\', '\\\\')
        qs = time.time()
        feat_datapoint_cnt = int(eachfeat.cnt * rand_proportion)
        data = prepare_data(table_name, feat, eachfeat.cnt, feat_datapoint_cnt, include_zero, use_random)
        qe = time.time()
        best_fit_name, max_ll, best_fit_paramms, dist_stat = best_fit_distribution(data)
        
        
        dist_confidence = {}
        """Inside if is the process of checking the significance of the best distribution.""" 
        if confidence:
            # save first result from the previous run of "best_fit_distribution"
            ll_dict = {}
            for k, v in dist_stat.items():
                # v is a list containing ll & params
                if (v[0] != float("-inf")) & (v[0] != float("inf")):
                    ll_dict[k] = [v[0]]
                else:
                    ll_dict[k] = []
                
            # repeat the process for another 49 times (which totally becomes 50 with the original best_fit_dist)
            for i in range(49):
                best_fit_name, max_ll, best_fit_paramms, dist_stat = best_fit_distribution(data)
                for k, v in dist_stat.items():
                    # This if is for handling inf & -inf. These 2 will set all other statistics to nan
                    if (v[0] != float("-inf")) & (v[0] != float("inf")):
                        ll_dict[k] += [v[0]]
            # now you have 50 ll for each distribution. Calculate confidence interval of the winner
            for k, v in ll_dict.items():
                v_mn = np.mean(v)
                v_std = np.std(v)
                dist_confidence[k] = (v_mn, v_std, v_mn + 2*v_std, v_mn-2*v_std, len(v))
        usr_best_fit.append([feat, eachfeat.cnt, feat_datapoint_cnt, best_fit_name, max_ll, best_fit_paramms,\
                            dist_stat, dist_confidence])
                
        beste = time.time()
        query_time += (qe-qs)
        fit_time += (beste-qe)
        x = str(cntr) + ' out of ' + str(feat_cnt) + ', ' + feat + '-> query exec: ' \
        + str(round(qe-qs)) + 's, fit: ' + str(round(beste-qe)) + 's'
        print '\r', x, 
        #print x
        cntr += 1
    etime = time.time()
    print
    print('overall time: ' + str(round(etime-stime)) + 's -> query exec: ' + str(round(query_time)) + \
          's , fit: ' + str(round(fit_time)) + 's') 
    df = pd.DataFrame(usr_best_fit, \
                      columns=['feat', 'total_cnt', 'nonzero_cnt', 'best_fitted',  \
                               'best_statistic', 'best_params', 'dist_stat', 'confidence'])
    feat_dist = df.groupby('best_fitted').feat.count()
    print(feat_dist)

    df = df.sort_values('best_statistic')
    return df

# %% [markdown]
# # Draw Two plots for the data
# One including all tested distributions and the other the best fitted one
#
# **Args:**
# * table_name -> to fetch data from
# * feature -> specific feature that we want to fetch data for
#
# **What it does?**
# draws two plots for this data
# * First one contains all the distributions over the histogram of the data with their MLE parameters.
# For this we call function best_fit_distribution with a previously initiated subplot ax with the data ranges.
# * Second one contains the winner, the fitted distribution with minimum SSE among all.
# For this we generate a pdf out of 10000 samples using the parameters of the winning distribution and draw it.

# %%
def draw_plots(data, title, useAnderson=False, plot_pdf=False):
    """Draw plot including real data cdf and also all distributions' cdfs"""
    plt.figure(figsize=(12,8))
    sorted_data = np.sort(data).tolist()
    if plot_pdf:
        plt.hist(sorted_data, bins=200, normed=True, alpha=0.2, color='purple')
    else:
        N = len(sorted_data)
        frequencies = np.arange(1, N+1)/N
        plt.plot(sorted_data, frequencies, color='black', linewidth='3')
        
    ax=plt.subplot(111)
    # Save plot limits
    dataYLim = ax.get_ylim()
    dataXLim = ax.get_xlim()
    
    # Find best fit distribution
    if useAnderson:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = \
        best_anderson_fit_distribution(sorted_data, ax, plot_pdf)
    else:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = best_fit_distribution(sorted_data, ax, plot_pdf)
    ax.legend(loc='upper right')
    best_dist = getattr(ss, best_fit_name)

    # Update plots
    data_array=np.asarray(data)    
    num_of_zeros = len(data_array[data_array==Zero])
    ax.set_ylim(dataYLim)
    ax.set_xlim(dataXLim)
    ax.set_title(str(title) + ',' + best_fit_name + '\n ' + str(num_of_zeros) + '\n All Fitted Distributions')
    ax.set_xlabel('Group Norm')
    ax.set_ylabel('Frequency')
    plt.show()
    plt.close()
    return (best_fit_name, best_sse, best_fit_paramms, ax)

# %% [markdown]
# # Putting all together

# %%
def dist_plus_nBestWorst(table_name, n=4, include_zero=True, plot_cdf=True, plot_pdf=True, anderson=False,\
                        confidence = False):
    df = find_best_fit_for_all_feats(table_name, include_zero=include_zero, confidence=confidence)
    print('\n 4 Best Fitted Distributions')
    for idx, eachRow in df.head(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        #pdb.set_trace()
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    print('\n 4 Worst Fitted Distributions')
    for idx, eachRow in df.tail(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    return df

# %% [markdown]
# # LIWC County Level

# %%
ndf_liwc_cnty_wZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16', plot_cdf=False, \
                                          confidence = True)
#df_liwc_cnty_noZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16', include_zero=False, \
#                                          confidence = True)
# Out:
# 999 data points for each feature
# 10000 random data points will be selected instead, if it is smaller
# 64 unique features
# 1 out of 64, ACHIEV-> query exec: 0.0s, fit: 30.0s
# overall time: 30.0s -> query exec: 0.0s , fit: 30.0s
# best_fitted
# powerlaw    1
# Name: feat, dtype: int64
#
#  4 Best Fitted Distributions
#  4 Worst Fitted Distributions

# %% [markdown]
# # Results for LIWC features including zeros

# %%
cntr = 1

not_failure = {}
for idx, x in df_liwc_cnty_wZero.iterrows():
    #print cntr,x.feat,
    #for k, d in x.dist_stat.items():
    #    print(k[0] + str(d[2]) + ", "),
    #    if str(d[2])[0] == "T":
    #        permutation_res[k] += 1
    #print    
    print cntr, x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[0]) + ", "),

    print(x.best_fitted)
    tf = {}
    for k, v in x.confidence.items():
        tf[k] = True
        for other_k, other_v in x.confidence.items():
            # v[0]: current distribution "mean"
            # v[2]: current distribution "mean + 2std"
            # other_v[3]: other distribution "mean - 2std"
            if (other_k != k) and (v[0] < other_v[3]):
                tf[k] = False
    for k, v in x.confidence.items():        
        print(k + ":  " + str(v[4]) + ", " + str(int(v[0])) + ", " + str(tf[k]))
        if k not in not_failure:
            not_failure[k] = 0
        if tf[k]:
            not_failure[k] += 1
    print
    cntr+=1

print not_failure
# Out:
# 1 FUNC f192.56,  l528.15,  p-inf,  n524.78,  lognorm
# fisk:  50, 450, False
# lognorm:  50, 549, True
# powerlaw:  26, 40, False
# norm:  50, 550, True
#
# 2 RELATIV f992.78,  l944.04,  p604.14,  n921.91,  fisk
# fisk:  50, 1004, True
# lognorm:  50, 952, False
# powerlaw:  22, 471, False
# norm:  50, 935, False
#
# 3 VERBS f1006.74,  l937.76,  p-inf,  n860.66,  fisk
# fisk:  50, 1018, True
# lognorm:  50, 979, True
# powerlaw:  24, 1167, True
# norm:  50, 931, False
#
# 4 COGMECH f1043.25,  l1024.55,  p-inf,  n999.98,  fisk
# fisk:  50, 1022, True
# lognorm:  50, 1004, True
# powerlaw:  25, 1099, True
# norm:  50, 979, False
#
# 5 PRONOUN f1051.01,  l1033.53,  p911.97,  n1032.15,  fisk
# fisk:  50, 1045, True
# lognorm:  50, 1024, True
# powerlaw:  25, 934, False
# norm:  50, 1023, True
#
# 6 PRESENT f1134.86,  l1093.46,  p-inf,  n1061.78,  fisk
# fisk:  50, 1159, True
# lognorm:  50, 1126, True
# powerlaw:  23, 1479, True
# norm:  50, 1113, False
#
# 7 PREP f1162.13,  l1107.98,  p508.37,  n1112.81,  fisk
# fisk:  50, 1153, True
# lognorm:  50, 1089, False
# powerlaw:  28, 667, False
# norm:  50, 1081, False
#
# 8 AFFECT f1188.27,  l1160.38,  p-inf,  n1065.96,  fisk
# fisk:  50, 1262, False
# lognorm:  50, 1192, False
# powerlaw:  23, 2040, True
# norm:  50, 1133, False
#
# 9 SPACE f1190.16,  l1156.8,  p926.3,  n1113.89,  fisk
# fisk:  50, 1177, True
# lognorm:  50, 1136, False
# powerlaw:  31, 916, False
# norm:  50, 1083, False
#
# 10 PPRON f1181.51,  l1166.18,  p1493.49,  n1166.31,  powerlaw
# fisk:  50, 1184, True
# lognorm:  50, 1166, True
# powerlaw:  26, 1217, True
# norm:  50, 1164, True
#
# 11 POSEMO f1654.43,  l1262.08,  p-inf,  n1103.13,  fisk
# fisk:  50, 1570, False
# lognorm:  50, 1293, False
# powerlaw:  28, 2787, True
# norm:  50, 1201, False
#
# 12 AUXVB f1212.09,  l1183.75,  p1741.69,  n1134.04,  powerlaw
# fisk:  50, 1155, False
# lognorm:  50, 1111, False
# powerlaw:  24, 1798, True
# norm:  50, 1012, False
#
# 13 ARTICLE f1524.42,  l1279.49,  p1969.79,  n1252.75,  powerlaw
# fisk:  50, 1419, True
# lognorm:  50, 1276, True
# powerlaw:  35, 1631, True
# norm:  50, 1240, False
#
# 14 I f2003.45,  l1286.25,  p1924.07,  n1271.55,  fisk
# fisk:  50, 1518, True
# lognorm:  50, 1275, True
# powerlaw:  27, 1921, True
# norm:  50, 1256, False
#
# 15 TIME f1216.44,  l1202.22,  p2200.03,  n1166.46,  powerlaw
# fisk:  50, 1280, True
# lognorm:  50, 1218, True
# powerlaw:  23, 1445, True
# norm:  50, 1178, False
#
# 16 SOCIAL f1159.2,  l1154.82,  p2242.9,  n1118.66,  powerlaw
# fisk:  50, 1177, True
# lognorm:  50, 1155, True
# powerlaw:  21, 1642, True
# norm:  50, 1122, False
#
# 17 ADVERBS f1862.19,  l1371.6,  p2607.5,  n1281.01,  powerlaw
# fisk:  50, 1728, False
# lognorm:  50, 1380, False
# powerlaw:  31, 2665, True
# norm:  50, 1300, False
#
# 18 CONJ f3592.02,  l1482.21,  p3008.38,  n1464.37,  fisk
# fisk:  50, 3367, True
# lognorm:  50, 1466, False
# powerlaw:  44, 3200, True
# norm:  50, 1430, False
#
# 19 LEISURE f3067.2,  l1508.32,  p4117.82,  n1400.05,  powerlaw
# fisk:  50, 2941, False
# lognorm:  50, 1500, False
# powerlaw:  38, 4083, True
# norm:  50, 1390, False
#
# 20 PERCEPT f2833.93,  l1535.93,  p4225.92,  n1440.64,  powerlaw
# fisk:  50, 3909, False
# lognorm:  50, 1537, False
# powerlaw:  28, 4344, True
# norm:  50, 1393, False
#
# 21 IPRON f3412.15,  l1432.1,  p4591.29,  n1392.1,  powerlaw
# fisk:  50, 3117, False
# lognorm:  50, 1430, False
# powerlaw:  30, 4295, True
# norm:  50, 1385, False
#
# 22 MOTION f4437.2,  l1615.53,  p4641.46,  n1508.84,  powerlaw
# fisk:  50, 4027, True
# lognorm:  50, 1622, False
# powerlaw:  28, 4622, True
# norm:  50, 1492, False
#
# 23 PAST f4217.16,  l1626.91,  p4762.88,  n1448.37,  powerlaw
# fisk:  50, 4582, True
# lognorm:  50, 1799, False
# powerlaw:  32, 4492, True
# norm:  50, 1365, False
#
# 24 INSIGHT f4896.02,  l3212.67,  p-inf,  n1583.99,  fisk
# fisk:  50, 5650, False
# lognorm:  50, 3100, False
# powerlaw:  25, 6626, True
# norm:  50, 1601, False
#
# 25 INCL f4178.46,  l1502.76,  p4924.96,  n1427.17,  powerlaw
# fisk:  50, 3425, True
# lognorm:  50, 1484, False
# powerlaw:  25, 4232, True
# norm:  50, 1380, False
#
# 26 BIO f5089.99,  l1522.63,  p-inf,  n1460.71,  fisk
# fisk:  50, 4463, True
# lognorm:  50, 1530, False
# powerlaw:  27, 4913, True
# norm:  50, 1478, False
#
# 27 EXCL f4616.33,  l1669.65,  p5357.69,  n1533.05,  powerlaw
# fisk:  50, 4765, True
# lognorm:  50, 1664, False
# powerlaw:  28, 5157, True
# norm:  50, 1503, False
#
# 28 QUANT f5491.26,  l1695.86,  p-inf,  n1581.01,  fisk
# fisk:  50, 5437, True
# lognorm:  50, 1690, False
# powerlaw:  19, 4574, False
# norm:  50, 1583, False
#
# 29 TENTAT f5631.61,  l2565.83,  p4716.2,  n1563.52,  fisk
# fisk:  50, 5719, True
# lognorm:  50, 2167, False
# powerlaw:  31, 6335, True
# norm:  50, 1614, False
#
# 30 ACHIEV f3898.02,  l2460.6,  p6252.18,  n1638.39,  powerlaw
# fisk:  50, 5350, False
# lognorm:  50, 1902, False
# powerlaw:  20, 6347, True
# norm:  50, 1585, False
#
# 31 NEGEMO f6188.49,  l2672.38,  p6319.01,  n1705.3,  powerlaw
# fisk:  50, 6443, True
# lognorm:  50, 2559, False
# powerlaw:  24, 6446, True
# norm:  50, 1660, False
#
# 32 SEE f4830.95,  l6563.78,  p6553.93,  n1541.19,  lognorm
# fisk:  50, 5541, True
# lognorm:  50, 3857, False
# powerlaw:  29, 6098, True
# norm:  50, 1547, False
#
# 33 CAUSE f6576.59,  l5865.07,  p-inf,  n1469.64,  fisk
# fisk:  50, 7258, True
# lognorm:  50, 4990, False
# powerlaw:  28, 6305, True
# norm:  50, 1680, False
#
# 34 INGEST f6749.99,  l4426.57,  p-inf,  n1607.78,  fisk
# fisk:  50, 6284, True
# lognorm:  50, 3607, False
# powerlaw:  29, 7378, True
# norm:  50, 1654, False
#
# 35 WORK f6169.9,  l4267.92,  p6924.78,  n1583.55,  powerlaw
# fisk:  50, 6334, True
# lognorm:  50, 3184, False
# powerlaw:  25, 6352, True
# norm:  50, 1556, False
#
# 36 CERTAIN f7055.98,  l5993.41,  p7032.14,  n1650.73,  fisk
# fisk:  50, 7672, True
# lognorm:  50, 5764, False
# powerlaw:  16, 7360, True
# norm:  50, 1619, False
#
# 37 HOME f7146.83,  l6821.68,  p6376.5,  n1725.32,  fisk
# fisk:  50, 7811, True
# lognorm:  50, 5755, False
# powerlaw:  25, 6695, False
# norm:  50, 1674, False
#
# 38 SEXUAL f2476.24,  l7246.07,  p-inf,  n2115.29,  lognorm
# fisk:  50, 6853, False
# lognorm:  50, 7746, True
# powerlaw:  24, 10152, True
# norm:  50, 2093, False
#
# 39 NEGATE f7375.57,  l1852.3,  p6502.91,  n1752.85,  fisk
# fisk:  50, 7201, True
# lognorm:  50, 2786, False
# powerlaw:  31, 7231, True
# norm:  50, 1757, False
#
# 40 HUMANS f7468.42,  l5194.66,  p-inf,  n1850.58,  fisk
# fisk:  50, 7934, False
# lognorm:  50, 6072, False
# powerlaw:  28, 9277, True
# norm:  50, 1836, False
#
# 41 WE f8384.82,  l7513.74,  p-inf,  n1714.54,  fisk
# fisk:  50, 8260, True
# lognorm:  50, 6175, False
# powerlaw:  25, 7729, True
# norm:  50, 1677, False
#
# 42 DISCREP f8422.55,  l7123.43,  p8465.08,  n1763.89,  powerlaw
# fisk:  50, 8177, True
# lognorm:  50, 5042, False
# powerlaw:  28, 8702, True
# norm:  50, 1721, False
#
# 43 YOU f7785.13,  l1789.0,  p8521.85,  n1608.65,  powerlaw
# fisk:  50, 7352, False
# lognorm:  50, 4935, False
# powerlaw:  30, 8309, True
# norm:  50, 1580, False
#
# 44 MONEY f8528.33,  l4380.93,  p-inf,  n1819.85,  fisk
# fisk:  50, 9013, True
# lognorm:  50, 6180, False
# powerlaw:  25, 7900, True
# norm:  50, 1844, False
#
# 45 RELIG f8819.48,  l4947.07,  p-inf,  n1825.49,  fisk
# fisk:  50, 9180, True
# lognorm:  50, 7627, False
# powerlaw:  35, 8327, True
# norm:  50, 1798, False
#
# 46 NUMBERS f8885.21,  l6623.73,  p-inf,  n1674.24,  fisk
# fisk:  50, 8483, True
# lognorm:  50, 6271, False
# powerlaw:  18, 7121, False
# norm:  50, 1678, False
#
# 47 ASSENT f8939.26,  l6515.96,  p-inf,  n1453.08,  fisk
# fisk:  50, 8678, True
# lognorm:  50, 6884, False
# powerlaw:  26, 8027, True
# norm:  50, 1615, False
#
# 48 INHIB f8693.84,  l9321.09,  p6416.83,  n1789.99,  lognorm
# fisk:  50, 8787, True
# lognorm:  50, 7172, False
# powerlaw:  29, 6942, False
# norm:  50, 1754, False
#
# 49 FAMILY f9349.0,  l6308.96,  p-inf,  n1597.25,  fisk
# fisk:  50, 8847, True
# lognorm:  50, 6982, False
# powerlaw:  25, 8476, True
# norm:  50, 1663, False
#
# 50 BODY f9349.46,  l9105.4,  p8645.63,  n1927.35,  fisk
# fisk:  50, 8699, True
# lognorm:  50, 6688, False
# powerlaw:  23, 10112, True
# norm:  50, 1922, False
#
# 51 FUTURE f9958.31,  l7530.39,  p-inf,  n1721.23,  fisk
# fisk:  50, 9239, True
# lognorm:  50, 6545, False
# powerlaw:  22, 7625, False
# norm:  50, 1767, False
#
# 52 ANGER f10182.57,  l7665.55,  p7727.01,  n2007.33,  fisk
# fisk:  50, 8913, True
# lognorm:  50, 7979, True
# powerlaw:  24, 9856, True
# norm:  50, 1972, False
#
# 53 HEALTH f9373.85,  l9966.77,  p10394.08,  n1962.3,  powerlaw
# fisk:  50, 9705, True
# lognorm:  50, 8409, True
# powerlaw:  24, 10046, True
# norm:  50, 1798, False
#
# 54 SHEHE f10412.09,  l8595.71,  p8192.88,  n1963.55,  fisk
# fisk:  50, 9488, True
# lognorm:  50, 8411, True
# powerlaw:  31, 8511, True
# norm:  50, 1905, False
#
# 55 FEEL f9116.24,  l10309.02,  p10683.54,  n1850.46,  powerlaw
# fisk:  50, 9074, True
# lognorm:  50, 7704, False
# powerlaw:  48, 9913, True
# norm:  50, 1779, False
#
# 56 HEAR f10691.72,  l7201.48,  p7480.29,  n1895.43,  fisk
# fisk:  50, 10593, True
# lognorm:  50, 7271, False
# powerlaw:  42, 7926, True
# norm:  50, 1884, False
#
# 57 THEY f10243.81,  l11330.46,  p-inf,  n1955.65,  lognorm
# fisk:  50, 10995, True
# lognorm:  50, 8850, True
# powerlaw:  21, 9287, True
# norm:  50, 1885, False
#
# 58 FILLER f7328.38,  l11756.78,  p9357.51,  n2112.49,  lognorm
# fisk:  50, 8153, True
# lognorm:  50, 9681, True
# powerlaw:  34, 10731, True
# norm:  50, 2079, False
#
# 59 SAD f12175.13,  l9846.87,  p11233.69,  n1912.0,  fisk
# fisk:  50, 10821, True
# lognorm:  50, 7785, False
# powerlaw:  44, 10466, True
# norm:  50, 1942, False
#
# 60 ANX f12595.66,  l8536.84,  p13444.99,  n2228.26,  powerlaw
# fisk:  50, 13201, False
# lognorm:  50, 9966, False
# powerlaw:  27, 13875, True
# norm:  50, 1977, False
#
# 61 SWEAR f14424.32,  l4355.07,  p-inf,  n2114.74,  fisk
# fisk:  50, 13561, True
# lognorm:  50, 9513, False
# powerlaw:  27, 9234, False
# norm:  50, 2219, False
#
# 62 FRIENDS f12293.96,  l12305.04,  p15728.53,  n2273.75,  powerlaw
# fisk:  50, 12268, True
# lognorm:  50, 10069, False
# powerlaw:  38, 13621, True
# norm:  50, 2176, False
#
# 63 NONFLU f16400.33,  l13898.84,  p-inf,  n1894.54,  fisk
# fisk:  50, 15996, True
# lognorm:  50, 11776, False
# powerlaw:  25, 15927, True
# norm:  50, 2328, False
#
# 64 DEATH f17194.21,  l10744.39,  p-inf,  n-620.6,  fisk
# fisk:  50, 16189, True
# lognorm:  50, 11068, False
# powerlaw:  22, 13095, False
# norm:  50, 318, False
#
# {'fisk': 50, 'lognorm': 16, 'powerlaw': 52, 'norm': 3}

# %% [markdown]
# # Choose any feature and see plot for that feature distribution.

# %%
table_name = 'feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16'
feat = df_liwc_cnty_wZero[df_liwc_cnty_wZero.feat == 'FUNC'].iloc[0]
data = prepare_data(table_name, str(feat.feat), feat.total_cnt, feat.nonzero_cnt, include_zero=True)
draw_plots(data, str(feat.feat), plot_pdf=True)
# Out:
# ('fisk',
#  567.00625755252827,
#  (106590007.57279068, -4626386.0902652275, 4626386.3539039977),
#  <matplotlib.axes.AxesSubplot at 0x7f0452aa58d0>)
