# %% [markdown]
# # Database Initialization

# %%
from __future__ import division
db = 'twitterGender'
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
myDB = URL(drivername='mysql', database=db, query={ 'read_default_file' : '/home/fatal/.my.cnf' })
engine = create_engine(name_or_url=myDB, encoding='utf8')
#conn = engine.connect()

# %% [markdown]
# # Necessary Libraries & Global Variables

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy
import scipy.stats as ss
import pandas as pd
import warnings
import random

import time
import pdb

#SMALL_VAL = 0.0000001
SMALL_VAL = 1
Zero = 0
RAND_COUNT = 10000
group_id_cnt = 0

# %% [markdown]
# # Find Best Fit Distribution
# ## Function name: best_fit_distribution
# **Args:**
# * data -> a series of data values (like group norms in our case)
# * bins -> how many bins we want to divide the data into (default = 200)
# * ax -> axes subplots (default None)
#   * subplot of the data with x and y limits set
#   * If given, this function will add histogram of data + all different distribution lines to this subplot
#
# **Returns:**
# * Best_Distribution_name -> winner among all distributions
# * Best_SSE -> Minimum sum of squared error
# * Best_params -> parameters of the best distribution which has at least two parameters of "Location" and "Scale" + any additional parameters based on the distribution type
#
# **What it does?**
# * Creates a histogram of the data divided to <BINS> bins
# * Sets x as the center of each bin
# * Sets y as the frequency value of each bin (normed = True)
# * Finds the best fit distribution among previously defined distributions based on the SSE of the returned value and the actual value
#   * Uses scipy.stats distribution methods **fit** and **pdf**
#   * scipy.stats current Distributions are **norm**, **expon**, and **lognorm** for now
# * If ax is set, it adds histogram and all the distributions lines with their MLE parameters to that

# %%
# Create models from data
def best_fit_distribution(input_data, ax=None, plot_pdf = False, test_significance=True):
    """Model data by finding best fit distribution to data"""
    DISTRIBUTIONS = [
        #ss.norm, ss.lognorm, ss.expon, ss.powerlaw
        ss.norm, ss.lognorm, ss.powerlaw, ss.fisk
    ]
    # Best holders
    best_distribution = ss.norm
    best_params = (0.0, 1.0)
    best_ll = -1 * np.inf
    significant = True

    dist_ll = {}

    N = len(input_data)
    random.shuffle(input_data)
    train_end = int(N/2)
    data = np.sort(input_data[0:train_end])
    test = np.sort(input_data[train_end:N])
    #data = np.sort(input_data)
    #test = np.sort(input_data)
    input_data = np.sort(input_data)
    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')
                
                
                # fit dist to data
                params = distribution.fit(data)
                
                logs = distribution.logpdf(test, loc=params[-2], scale=params[-1], *params[:-2])
                logs[logs == float("-inf")] = -50
                ll = np.sum(logs)
                #if ll == float("-inf"):                    
                #    pdb.set_trace()
                #    distribution.fit(data)
                #    distribution.pdf(test[-1], loc=params[-2], scale=params[-1], *params[:-2])

                dist_ll[distribution.name] = [round(ll, 2), params]
                # if axis pass in add to plot
                try:
                    if ax:
                        # Calculate fitted PDF and error with fit in distribution
                        if plot_pdf:
                            y = distribution.pdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        else:
                            y = distribution.cdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        pd.Series(y, input_data). \
                        plot(ax=ax, label=distribution.name + str(round(ll, 2)))
                except Exception as detail:
                    print('Plotting Runtime Error: ' + str(detail))
                    pass
                # identify if this distribution is better
                if best_ll < ll:
                    best_distribution = distribution
                    best_params = params
                    best_ll = ll

        except Exception as detail:
            print('Runtime Error: ' + str(detail))
            pass
            
    return (best_distribution.name, best_ll, best_params, dist_ll)

# %% [markdown]
# # Distribution of best fit distributions among all different features
#
#  Gives you count of features in each distribution
#  And also best fitted distribution to each feature

# %%
def fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random=True):
    if use_random and group_id_cnt > RAND_COUNT:
        fetch_data_query = "select * from {0} join \
        (select ceil(rand()*{3}) as id from {0} where feat='{1}') as r2 using(id) limit {2}" \
        .format(table_name, feat, feat_needed_cnt, feat_total_cnt)
    else:
        fetch_data_query = "select * from {0} where feat = '{1}'" \
        .format(table_name, feat)        
    raw_df = pd.read_sql(fetch_data_query, con=engine)
    # convert group_norms to integers by multiplying them by a large number and rounding to int
    raw_df.group_norm = raw_df.group_norm * 100000
    raw_df.group_norm = raw_df.group_norm.astype(int)
    return raw_df
    
    
def prepare_data(table_name, feat, feat_total_cnt, feat_needed_cnt, include_zero=True, use_random=True):
    raw_df = fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random)
    data = raw_df.group_norm.tolist()
    total_cnt = group_id_cnt
    if use_random and total_cnt > RAND_COUNT:
        total_cnt = RAND_COUNT
    nonExisting_cnt = max(0, int(total_cnt - len(data)))
    # Appending zero for those that does not use this feature at all
    # By removing this line you can find the best 
    if include_zero:
        data = data + ([Zero]*nonExisting_cnt)
    return np.sort(data).tolist()

def find_best_fit_for_all_feats(table_name, include_zero=True, use_random=True, \
                                confidence=False):
    pval_threshold = 0.05
    cntr = 1
    usr_best_fit = []
    query_time = 0
    fit_time = 0

    # Load DATA from DB
    stime = time.time()
    global group_id_cnt
    #pdb.set_trace()
    group_id_cnt = pd.read_sql('select count(distinct group_id) cnt from ' + table_name, con=engine)
    group_id_cnt = group_id_cnt.cnt[0]
    print(str(group_id_cnt) + ' data points for each feature')
    print(str(RAND_COUNT) + ' random data points will be selected instead, if it is smaller')
    # Load distinct features
    features = pd.read_sql('select feat, count(*) cnt from ' + table_name + ' group by feat', con=engine)
    feat_cnt = len(features)
    print(str(feat_cnt) + ' unique features' )
        
    if include_zero:
        rand_proportion = min(RAND_COUNT/group_id_cnt, 1)
    else:
        rand_proportion = 1
    #pdb.set_trace()
    # Load data feature by feature and find the best distribution for each feature
    for index, eachfeat in features.iterrows():
        feat = eachfeat.feat
        feat = feat.replace("'", "''").replace("%", "%%").replace('\\', '\\\\')
        qs = time.time()
        feat_datapoint_cnt = int(eachfeat.cnt * rand_proportion)
        data = prepare_data(table_name, feat, eachfeat.cnt, feat_datapoint_cnt, include_zero, use_random)
        qe = time.time()
        best_fit_name, max_ll, best_fit_paramms, dist_stat = best_fit_distribution(data)
        
        dist_confidence = {}
        
        # Calculate confidence interval using bootstrapping
        #if confidence:
        #    # save first result from the previous run of "best_fit_distribution"
        #    ll_dict = {}
        #    for k, v in dist_stat.items():
        #        # v is a list containing ll & params
        #        if (v[0] != float("-inf")) & (v[0] != float("inf")):
        #            ll_dict[k] = [v[0]]
        #        else:
        #            ll_dict[k] = []
        #        
        #    #repeat the process for another 49 times
        #    for i in range(49):
        #        best_fit_name, max_ll, best_fit_paramms, dist_stat = best_fit_distribution(data)
        #        for k, v in dist_stat.items():
        #            # This if is for handling inf & -inf. These 2 will set all other statistics to nan
        #            if (v[0] != float("-inf")) & (v[0] != float("inf")):
        #                ll_dict[k] += [v[0]]
        #    # now you have 50 ll for each distribution. Calculate confidence interval of the winner
        #    for k, v in ll_dict.items():
        #        v_mn = np.mean(v)
        #        v_std = np.std(v)
        #        dist_confidence[k] = (v_mn, v_std, v_mn + 2*v_std, v_mn-2*v_std, len(v))
                
                
        usr_best_fit.append([feat, eachfeat.cnt, feat_datapoint_cnt, best_fit_name, max_ll, best_fit_paramms,\
                            dist_stat, dist_confidence])
                            
        beste = time.time()
        query_time += (qe-qs)
        fit_time += (beste-qe)
        x = str(cntr) + ' out of ' + str(feat_cnt) + ', ' + feat + '-> query exec: ' \
        + str(round(qe-qs)) + 's, fit: ' + str(round(beste-qe)) + 's'
        print '\r', x, 
        #print x
        cntr += 1
    etime = time.time()
    print
    print('overall time: ' + str(round(etime-stime)) + 's -> query exec: ' + str(round(query_time)) + \
          's , fit: ' + str(round(fit_time)) + 's') 
    df = pd.DataFrame(usr_best_fit, \
                      columns=['feat', 'total_cnt', 'nonzero_cnt', 'best_fitted',  \
                               'best_statistic', 'best_params', 'dist_stat', 'confidence'])
    feat_dist = df.groupby('best_fitted').feat.count()
    print(feat_dist)

    df = df.sort_values('best_statistic')
    return df

# %% [markdown]
# # Draw Two plots for the data
# One including all tested distributions and the other the best fitted one
#
# **Args:**
# * table_name -> to fetch data from
# * feature -> specific feature that we want to fetch data for
#
# **What it does?**
# draws two plots for this data
# * First one contains all the distributions over the histogram of the data with their MLE parameters.
# For this we call function best_fit_distribution with a previously initiated subplot ax with the data ranges.
# * Second one contains the winner, the fitted distribution with minimum SSE among all.
# For this we generate a pdf out of 10000 samples using the parameters of the winning distribution and draw it.

# %%
def draw_plots(data, title, useAnderson=False, plot_pdf=False):
    """Draw plot including real data cdf and also all distributions' cdfs"""
    plt.figure(figsize=(12,8))
    sorted_data = np.sort(data).tolist()
    if plot_pdf:
        plt.hist(sorted_data, bins=200, normed=True, alpha=0.2, color='purple')
    else:
        N = len(sorted_data)
        frequencies = np.arange(1, N+1)/N
        plt.plot(sorted_data, frequencies, color='black', linewidth='3')
        
    ax=plt.subplot(111)
    # Save plot limits
    dataYLim = ax.get_ylim()
    dataXLim = ax.get_xlim()
    
    # Find best fit distribution
    if useAnderson:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = \
        best_anderson_fit_distribution(sorted_data, ax, plot_pdf)
    else:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = best_fit_distribution(sorted_data, ax, plot_pdf)
    ax.legend(loc='upper right')
    best_dist = getattr(ss, best_fit_name)

    # Update plots
    data_array=np.asarray(data)    
    num_of_zeros = len(data_array[data_array==Zero])
    ax.set_ylim(dataYLim)
    ax.set_xlim(dataXLim)
    ax.set_title(str(title) + ',' + best_fit_name + '\n ' + str(num_of_zeros) + '\n All Fitted Distributions')
    ax.set_xlabel('Group Norm')
    ax.set_ylabel('Frequency')
    plt.show()
    plt.close()
    return (best_fit_name, best_sse, best_fit_paramms, ax)

# %% [markdown]
# # Putting all together

# %%
def dist_plus_nBestWorst(table_name, n=4, include_zero=True, plot_cdf=True, plot_pdf=True, anderson=False,\
                        confidence = False):
    df = find_best_fit_for_all_feats(table_name, include_zero=include_zero, confidence=confidence)
    print('\n 4 Best Fitted Distributions')
    for idx, eachRow in df.head(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    print('\n 4 Worst Fitted Distributions')
    for idx, eachRow in df.tail(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    return df

# %% [markdown]
# # LIWC County Level

# %%
df_liwc_cnty_wZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16', plot_cdf=False, \
                                          confidence = True)
#df_liwc_cnty_noZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16', include_zero=False, \
#                                          confidence = True)
# Out:
# 999 data points for each feature
# 10000 random data points will be selected instead, if it is smaller
# 64 unique features
# 64 out of 64, YOU-> query exec: 0.0s, fit: 0.0s
# overall time: 26.0s -> query exec: 0.0s , fit: 26.0s
# best_fitted
# fisk        36
# lognorm      4
# norm         3
# powerlaw    21
# Name: feat, dtype: int64
#
#  4 Best Fitted Distributions
#  4 Worst Fitted Distributions

# %% [markdown]
# # Results for LIWC features including zeros

# %%
cntr = 1

not_failure = {}
for idx, x in df_liwc_cnty_wZero.iterrows():
    #print cntr,x.feat,
    #for k, d in x.dist_stat.items():
    #    print(k[0] + str(d[2]) + ", "),
    #    if str(d[2])[0] == "T":
    #        permutation_res[k] += 1
    #print    
    print cntr, x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[0]) + ", "),

    print(x.best_fitted)
    tf = {}
    for k, v in x.confidence.items():
        tf[k] = True
        for other_k, other_v in x.confidence.items():
            # v[0]: current distribution "mean"
            # v[2]: current distribution "mean + 2std"
            # other_v[3]: other distribution "mean - 2std"
            if (other_k != k) and (v[0] < other_v[3]):
                tf[k] = False
    for k, v in x.confidence.items():        
        print(k + ":  " + str(v[4]) + ", " + str(int(v[0])) + ", " + str(tf[k]))
        if k not in not_failure:
            not_failure[k] = 0
        if tf[k]:
            not_failure[k] += 1
    print
    cntr+=1

print not_failure
# Out:
# 1 FUNC f561.63,  l542.4,  p200.4,  n541.05,  fisk
# fisk:  50, 485, False
# lognorm:  50, 552, True
# powerlaw:  50, 98, False
# norm:  50, 553, True
#
# 2 RELATIV f1005.94,  l956.79,  p458.59,  n944.98,  fisk
# fisk:  50, 1004, True
# lognorm:  50, 953, False
# powerlaw:  50, 485, False
# norm:  50, 936, False
#
# 3 PRONOUN f1058.92,  l1044.48,  p587.09,  n1047.34,  fisk
# fisk:  50, 1043, True
# lognorm:  50, 1024, True
# powerlaw:  50, 875, False
# norm:  50, 1023, True
#
# 4 PRESENT f1140.49,  l1091.4,  p693.87,  n1061.48,  fisk
# fisk:  50, 1159, True
# lognorm:  50, 1119, True
# powerlaw:  50, 1221, True
# norm:  50, 1104, False
#
# 5 PREP f1141.63,  l1101.61,  p847.98,  n1102.11,  fisk
# fisk:  50, 1147, True
# lognorm:  50, 1085, False
# powerlaw:  50, 647, False
# norm:  50, 1078, False
#
# 6 COGMECH f1036.2,  l1013.84,  p1167.33,  n982.2,  powerlaw
# fisk:  50, 1019, True
# lognorm:  50, 1001, True
# powerlaw:  50, 945, False
# norm:  50, 974, False
#
# 7 SPACE f1188.07,  l1155.26,  p1026.48,  n1125.02,  fisk
# fisk:  50, 1172, True
# lognorm:  50, 1130, True
# powerlaw:  50, 841, False
# norm:  50, 1074, False
#
# 8 TIME f1233.17,  l1216.19,  p783.42,  n1167.8,  fisk
# fisk:  50, 1299, True
# lognorm:  50, 1217, True
# powerlaw:  50, 1647, True
# norm:  50, 1176, False
#
# 9 AUXVB f1009.73,  l1128.94,  p1414.77,  n954.27,  powerlaw
# fisk:  50, 1159, True
# lognorm:  50, 1114, True
# powerlaw:  50, 1510, True
# norm:  50, 1002, False
#
# 10 VERBS f1000.55,  l973.23,  p1522.28,  n964.88,  powerlaw
# fisk:  50, 1020, True
# lognorm:  50, 980, True
# powerlaw:  50, 983, True
# norm:  50, 946, False
#
# 11 ARTICLE f1170.47,  l1266.64,  p1534.96,  n1223.9,  powerlaw
# fisk:  50, 1463, True
# lognorm:  50, 1270, True
# powerlaw:  50, 1641, True
# norm:  50, 1234, False
#
# 12 PPRON f1178.82,  l1161.17,  p1602.13,  n1156.04,  powerlaw
# fisk:  50, 1181, True
# lognorm:  50, 1163, True
# powerlaw:  50, 1125, False
# norm:  50, 1160, True
#
# 13 AFFECT f1204.5,  l1181.65,  p1716.89,  n1126.51,  powerlaw
# fisk:  50, 1248, False
# lognorm:  50, 1189, False
# powerlaw:  50, 1891, True
# norm:  50, 1128, False
#
# 14 SOCIAL f1149.81,  l1148.72,  p1923.46,  n1117.79,  powerlaw
# fisk:  50, 1166, True
# lognorm:  50, 1154, True
# powerlaw:  50, 1752, True
# norm:  50, 1119, True
#
# 15 I f1970.18,  l1270.97,  p1903.58,  n1253.82,  fisk
# fisk:  50, 1560, True
# lognorm:  50, 1276, True
# powerlaw:  50, 1588, True
# norm:  50, 1257, True
#
# 16 POSEMO f2216.63,  l1294.14,  p2250.08,  n1167.56,  powerlaw
# fisk:  50, 1649, True
# lognorm:  50, 1286, True
# powerlaw:  50, 2449, True
# norm:  50, 1179, False
#
# 17 ADVERBS f1387.04,  l1376.04,  p3223.25,  n1311.03,  powerlaw
# fisk:  50, 1824, False
# lognorm:  50, 1381, False
# powerlaw:  50, 2626, True
# norm:  50, 1302, False
#
# 18 CONJ f3493.2,  l1449.69,  p3532.27,  n1415.42,  powerlaw
# fisk:  50, 3366, True
# lognorm:  50, 1466, False
# powerlaw:  50, 3098, True
# norm:  50, 1424, False
#
# 19 PERCEPT f3527.89,  l1558.03,  p4032.88,  n1447.16,  powerlaw
# fisk:  50, 3843, True
# lognorm:  50, 1534, False
# powerlaw:  50, 4071, True
# norm:  50, 1386, False
#
# 20 INCL f3027.55,  l1479.02,  p4057.12,  n1382.52,  powerlaw
# fisk:  50, 3510, True
# lognorm:  50, 1483, False
# powerlaw:  50, 3972, True
# norm:  50, 1378, False
#
# 21 EXCL f4095.11,  l1674.9,  p4100.67,  n1502.83,  powerlaw
# fisk:  50, 4762, True
# lognorm:  50, 1669, False
# powerlaw:  50, 4817, True
# norm:  50, 1498, False
#
# 22 IPRON f3070.43,  l1443.39,  p4139.13,  n1414.61,  powerlaw
# fisk:  50, 3149, True
# lognorm:  50, 1434, False
# powerlaw:  50, 3503, True
# norm:  50, 1389, False
#
# 23 MOTION f3510.96,  l1618.34,  p4303.76,  n1509.31,  powerlaw
# fisk:  50, 4245, True
# lognorm:  50, 1615, False
# powerlaw:  50, 4415, True
# norm:  50, 1482, False
#
# 24 LEISURE f3227.43,  l1500.35,  p4498.07,  n1397.64,  powerlaw
# fisk:  50, 2977, False
# lognorm:  50, 1495, False
# powerlaw:  50, 3943, True
# norm:  50, 1380, False
#
# 25 PAST f4764.23,  l1566.61,  p4165.25,  n1123.17,  fisk
# fisk:  50, 4654, True
# lognorm:  50, 1827, False
# powerlaw:  50, 4397, True
# norm:  50, 1329, False
#
# 26 BIO f4495.93,  l1541.23,  p4818.11,  n1488.65,  powerlaw
# fisk:  50, 4480, True
# lognorm:  50, 1532, False
# powerlaw:  50, 4181, True
# norm:  50, 1482, False
#
# 27 SEE f4739.02,  l2128.87,  p5113.95,  n1581.25,  powerlaw
# fisk:  50, 5270, True
# lognorm:  50, 3897, False
# powerlaw:  50, 6127, True
# norm:  50, 1538, False
#
# 28 QUANT f5319.91,  l1688.41,  p4422.51,  n1560.78,  fisk
# fisk:  50, 5400, True
# lognorm:  50, 1692, False
# powerlaw:  50, 5072, True
# norm:  50, 1585, False
#
# 29 ACHIEV f5495.08,  l1764.48,  p4749.23,  n1469.71,  fisk
# fisk:  50, 4932, True
# lognorm:  50, 1825, False
# powerlaw:  50, 6194, True
# norm:  50, 1591, False
#
# 30 TENTAT f6097.16,  l1761.29,  p6068.25,  n1618.96,  fisk
# fisk:  50, 5689, True
# lognorm:  50, 2220, False
# powerlaw:  50, 6031, True
# norm:  50, 1612, False
#
# 31 INSIGHT f6036.16,  l3994.97,  p6316.62,  n1670.04,  powerlaw
# fisk:  50, 5494, False
# lognorm:  50, 3058, False
# powerlaw:  50, 6710, True
# norm:  50, 1618, False
#
# 32 NEGEMO f7004.52,  l1779.28,  p6878.59,  n1640.49,  fisk
# fisk:  50, 6468, True
# lognorm:  50, 2385, False
# powerlaw:  50, 6174, True
# norm:  50, 1656, False
#
# 33 INGEST f6605.85,  l3651.43,  p7024.81,  n1650.84,  powerlaw
# fisk:  50, 6346, True
# lognorm:  50, 3475, False
# powerlaw:  50, 7107, True
# norm:  50, 1646, False
#
# 34 CAUSE f7272.22,  l4574.92,  p5963.97,  n1796.68,  fisk
# fisk:  50, 7473, True
# lognorm:  50, 5148, False
# powerlaw:  50, 7654, True
# norm:  50, 1660, False
#
# 35 WORK f6417.0,  l1711.94,  p7464.35,  n1509.81,  powerlaw
# fisk:  50, 6465, True
# lognorm:  50, 3099, False
# powerlaw:  50, 5977, True
# norm:  50, 1548, False
#
# 36 NEGATE f7301.12,  l4187.84,  p7478.31,  n1770.94,  powerlaw
# fisk:  50, 7134, True
# lognorm:  50, 2492, False
# powerlaw:  50, 6937, True
# norm:  50, 1764, False
#
# 37 HOME f7564.6,  l6849.98,  p6747.45,  n1580.09,  fisk
# fisk:  50, 7763, True
# lognorm:  50, 5382, False
# powerlaw:  50, 7465, True
# norm:  50, 1671, False
#
# 38 DISCREP f7172.2,  l5389.37,  p7742.29,  n1732.08,  powerlaw
# fisk:  50, 7856, True
# lognorm:  50, 4512, False
# powerlaw:  50, 8196, True
# norm:  50, 1710, False
#
# 39 YOU f6444.84,  l3956.94,  p8160.39,  n1532.11,  powerlaw
# fisk:  50, 7319, True
# lognorm:  50, 4845, False
# powerlaw:  50, 7874, True
# norm:  50, 1583, False
#
# 40 FAMILY f8603.2,  l8050.37,  p8229.35,  n1722.75,  fisk
# fisk:  50, 8919, True
# lognorm:  50, 7567, False
# powerlaw:  50, 8198, True
# norm:  50, 1664, False
#
# 41 NUMBERS f7642.53,  l4420.22,  p8926.59,  n1622.39,  powerlaw
# fisk:  50, 8551, True
# lognorm:  50, 6798, False
# powerlaw:  50, 7991, True
# norm:  50, 1716, False
#
# 42 WE f8930.96,  l3660.29,  p8935.78,  n1776.49,  powerlaw
# fisk:  50, 8330, True
# lognorm:  50, 6465, False
# powerlaw:  50, 8613, True
# norm:  50, 1693, False
#
# 43 HUMANS f8389.9,  l7806.1,  p9247.89,  n1761.07,  powerlaw
# fisk:  50, 7849, True
# lognorm:  50, 5409, False
# powerlaw:  50, 9013, True
# norm:  50, 1820, False
#
# 44 INHIB f9306.07,  l6507.05,  p8685.46,  n1806.58,  fisk
# fisk:  50, 8965, True
# lognorm:  50, 7077, False
# powerlaw:  50, 6713, False
# norm:  50, 1735, False
#
# 45 THEY f9130.1,  l7929.57,  p9408.13,  n1302.5,  powerlaw
# fisk:  50, 11428, True
# lognorm:  50, 9403, True
# powerlaw:  50, 10225, True
# norm:  50, 1878, False
#
# 46 ASSENT f9471.83,  l2812.69,  p7596.93,  n1706.23,  fisk
# fisk:  50, 8779, True
# lognorm:  50, 7021, False
# powerlaw:  50, 7738, False
# norm:  50, 1610, False
#
# 47 MONEY f9521.7,  l7027.05,  p6354.06,  n1911.48,  fisk
# fisk:  50, 9193, True
# lognorm:  50, 6225, True
# powerlaw:  50, 7924, True
# norm:  50, 1859, False
#
# 48 FILLER f6560.06,  l9559.09,  p7249.19,  n2191.85,  lognorm
# fisk:  50, 9196, True
# lognorm:  50, 9387, True
# powerlaw:  50, 9481, True
# norm:  50, 2010, False
#
# 49 FUTURE f8608.67,  l9814.17,  p10063.96,  n1777.81,  powerlaw
# fisk:  50, 9166, True
# lognorm:  50, 6714, False
# powerlaw:  50, 8544, True
# norm:  50, 1778, False
#
# 50 RELIG f8397.16,  l5803.2,  p10075.92,  n1741.04,  powerlaw
# fisk:  50, 9195, True
# lognorm:  50, 8196, True
# powerlaw:  50, 8487, True
# norm:  50, 1779, False
#
# 51 CERTAIN f8929.67,  l3726.88,  p10080.55,  n1632.84,  powerlaw
# fisk:  50, 7819, True
# lognorm:  50, 5836, False
# powerlaw:  50, 7970, True
# norm:  50, 1640, False
#
# 52 SAD f10686.83,  l9365.63,  p8967.87,  n1992.62,  fisk
# fisk:  50, 10642, True
# lognorm:  50, 8729, True
# powerlaw:  50, 10529, True
# norm:  50, 1914, False
#
# 53 FEEL f9155.57,  l3759.77,  p10729.0,  n1798.21,  powerlaw
# fisk:  50, 9182, True
# lognorm:  50, 7447, False
# powerlaw:  50, 9858, True
# norm:  50, 1767, False
#
# 54 BODY f9493.84,  l10110.66,  p11113.51,  n2006.0,  powerlaw
# fisk:  50, 8449, True
# lognorm:  50, 7191, False
# powerlaw:  50, 9990, True
# norm:  50, 1931, False
#
# 55 HEAR f11155.55,  l5592.67,  p7773.83,  n1972.8,  fisk
# fisk:  50, 10056, True
# lognorm:  50, 6753, True
# powerlaw:  50, 8414, True
# norm:  50, 1848, False
#
# 56 ANGER f11464.14,  l7432.88,  p11630.6,  n1885.3,  powerlaw
# fisk:  50, 8593, True
# lognorm:  50, 7327, True
# powerlaw:  50, 9828, True
# norm:  50, 1968, False
#
# 57 HEALTH f10257.54,  l11853.21,  p8927.5,  n1769.47,  lognorm
# fisk:  50, 10127, True
# lognorm:  50, 7945, False
# powerlaw:  50, 10063, True
# norm:  50, 1791, False
#
# 58 SEXUAL f8524.73,  l8591.36,  p12253.27,  n2061.15,  powerlaw
# fisk:  50, 7633, True
# lognorm:  50, 6981, True
# powerlaw:  50, 10230, True
# norm:  50, 2076, False
#
# 59 FRIENDS f11447.17,  l12269.37,  p9343.64,  n2194.1,  lognorm
# fisk:  50, 12479, True
# lognorm:  50, 10201, True
# powerlaw:  50, 12177, True
# norm:  50, 2145, False
#
# 60 SHEHE f9413.44,  l12467.61,  p6986.3,  n1914.57,  lognorm
# fisk:  50, 9084, True
# lognorm:  50, 8110, True
# powerlaw:  50, 8752, True
# norm:  50, 1908, False
#
# 61 SWEAR f13376.87,  l5730.42,  p11110.18,  n2303.57,  fisk
# fisk:  50, 13914, True
# lognorm:  50, 9707, False
# powerlaw:  50, 10042, False
# norm:  50, 2226, False
#
# 62 ANX f12555.11,  l6805.49,  p13402.53,  n2230.36,  powerlaw
# fisk:  50, 13604, True
# lognorm:  50, 10444, False
# powerlaw:  50, 13005, True
# norm:  50, 1936, False
#
# 63 NONFLU f15210.97,  l5317.66,  p12686.71,  n2161.33,  fisk
# fisk:  50, 16072, True
# lognorm:  50, 10662, False
# powerlaw:  50, 13510, False
# norm:  50, 2208, False
#
# 64 DEATH f16195.79,  l11947.96,  p15050.68,  n15.7,  fisk
# fisk:  50, 15834, True
# lognorm:  50, 10714, False
# powerlaw:  50, 12974, False
# norm:  50, 759, False
#
# {'fisk': 59, 'lognorm': 23, 'powerlaw': 52, 'norm': 5}

# %% [markdown]
# # Choose any feature and see plot for that feature distribution.

# %%
table_name = 'feat$cat_LIWC2007$msgs_cnty_r1k$user_id$16to16'
for idx, feat in df_liwc_cnty_wZero.iterrows():
    #feat = df_liwc_cnty_wZero[df_liwc_cnty_wZero.feat == 'DEATH'].iloc[0]
    data = prepare_data(table_name, str(feat.feat), feat.total_cnt, feat.nonzero_cnt, include_zero=True)
    vls, bns = np.histogram(data, bins=500)
    bns = (bns[1:]+bns[:-1])/2
    plt.scatter(np.log(bns), np.log(vls))
    plt.title(feat.feat)
    plt.show()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
