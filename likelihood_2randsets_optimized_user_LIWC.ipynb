# %% [markdown]
# # Database Initialization

# %%
from __future__ import division
db = 'twitterGender'
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
myDB = URL(drivername='mysql', database=db, query={ 'read_default_file' : '/home/fatal/.my.cnf' })
engine = create_engine(name_or_url=myDB, encoding='utf8')
#conn = engine.connect()

# %% [markdown]
# # Necessary Libraries & Global Variables

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy
import scipy.stats as ss
import pandas as pd
import warnings
import random

import time
import pdb

#SMALL_VAL = 0.0000001
SMALL_VAL = 1
Zero = 0
RAND_COUNT = 10000
group_id_cnt = 0

# %% [markdown]
# # Permutation test to see if the distribution significantly fits a distribution

# %%
def fit_permutation_test(N, data, distribution, params, main_ll):
    ll_dist = []
    for i in range(100):
        rand_data = random.sample(data, N)
        res = distribution.logpdf(rand_data, loc=params[-2], scale=params[-1], *params[:-2])
        ll = np.sum(res)
        #excluding_inf = res[(res != float("inf")) & (res != float("-inf"))]
        #ll = np.sum(excluding_inf)
        ll_dist += [ll]
    #pdb.set_trace()
    return main_ll > (np.mean(ll_dist) + 2* np.std(ll_dist))

# %% [markdown]
# # Find Best Fit Distribution
# ## Function name: best_fit_distribution
# **Args:**
# * data -> a series of data values (like group norms in our case)
# * bins -> how many bins we want to divide the data into (default = 200)
# * ax -> axes subplots (default None)
#   * subplot of the data with x and y limits set
#   * If given, this function will add histogram of data + all different distribution lines to this subplot
#
# **Returns:**
# * Best_Distribution_name -> winner among all distributions
# * Best_SSE -> Minimum sum of squared error
# * Best_params -> parameters of the best distribution which has at least two parameters of "Location" and "Scale" + any additional parameters based on the distribution type
#
# **What it does?**
# * Creates a histogram of the data divided to <BINS> bins
# * Sets x as the center of each bin
# * Sets y as the frequency value of each bin (normed = True)
# * Finds the best fit distribution among previously defined distributions based on the SSE of the returned value and the actual value
#   * Uses scipy.stats distribution methods **fit** and **pdf**
#   * scipy.stats current Distributions are **norm**, **expon**, and **lognorm** for now
# * If ax is set, it adds histogram and all the distributions lines with their MLE parameters to that

# %%
# Create models from data
def best_fit_distribution(input_data, ax=None, plot_pdf = False, test_significance=True):
    """Model data by finding best fit distribution to data"""
    DISTRIBUTIONS = [
        ss.norm, ss.lognorm, ss.expon, ss.powerlaw
    ]
    # Best holders
    best_distribution = ss.norm
    best_params = (0.0, 1.0)
    best_ll = -1 * np.inf
    significant = True

    dist_ll = {}

    N = len(input_data)
    random.shuffle(input_data)
    train_end = int(N/2)
    data = np.sort(input_data[0:train_end])
    test = np.sort(input_data[train_end:N])
    #data = np.sort(input_data)
    #test = np.sort(input_data)
    input_data = np.sort(input_data)
    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')
                
                
                # fit dist to data
                params = distribution.fit(data)
                
                ll = np.sum(distribution.logpdf(test, loc=params[-2], scale=params[-1], *params[:-2]))
                #if test_significance:
                #    significant = fit_permutation_test(test, distribution, params)
                dist_ll[distribution.name] = [round(ll, 2), params]
                # if axis pass in add to plot
                try:
                    if ax:
                        # Calculate fitted PDF and error with fit in distribution
                        if plot_pdf:
                            y = distribution.pdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        else:
                            y = distribution.cdf(input_data, loc=params[-2], scale=params[-1], *params[:-2])
                        pd.Series(y, input_data). \
                        plot(ax=ax, label=distribution.name + str(round(ll, 2)))
                except Exception as detail:
                    print('Plotting Runtime Error: ' + str(detail))
                    pass
                # identify if this distribution is better
                if best_ll < ll:
                    best_distribution = distribution
                    best_params = params
                    best_ll = ll

        except Exception as detail:
            print('Runtime Error: ' + str(detail))
            pass

    rands = {}
    for distribution in DISTRIBUTIONS:
        params = dist_ll[distribution.name][1]
        rands[distribution.name] = distribution.rvs(loc=params[-2], scale=params[-1], size=N, *params[:-2])

    for distribution in DISTRIBUTIONS:
        all_except_curr_dist = test
        for k, x in rands.iteritems():
            if k != distribution.name:
                all_except_curr_dist = np.concatenate((all_except_curr_dist, x), axis=0)
        significant = fit_permutation_test(N, all_except_curr_dist, distribution, \
                                           dist_ll[distribution.name][1], dist_ll[distribution.name][0])        
        ks_sig, ks_pval = ss.kstest(test, distribution.name, dist_ll[distribution.name][1])
        ks_res = False
        if ks_pval >= 0.05:
            ks_res = True
        dist_ll[distribution.name] += [str(significant)[0] + str(ks_res)[0]]
            
    return (best_distribution.name, best_ll, best_params, dist_ll)

# %% [markdown]
# # Distribution of best fit distributions among all different features
#
#  Gives you count of features in each distribution
#  And also best fitted distribution to each feature

# %%
def fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random=True):
    if use_random and group_id_cnt > RAND_COUNT:
        fetch_data_query = "select * from {0} join \
        (select ceil(rand()*{3}) as id from {0} where feat='{1}') as r2 using(id) limit {2}" \
        .format(table_name, feat, feat_needed_cnt, feat_total_cnt)
    else:
        fetch_data_query = "select * from {0} where feat = '{1}'" \
        .format(table_name, feat)
    raw_df = pd.read_sql(fetch_data_query, con=engine)
    return raw_df
    
    
def prepare_data(table_name, feat, feat_total_cnt, feat_needed_cnt, include_zero=True, use_random=True):
    raw_df = fetch_data(table_name, feat, feat_total_cnt, feat_needed_cnt, use_random)
    data = raw_df.group_norm.tolist()
    total_cnt = group_id_cnt
    if use_random and total_cnt > RAND_COUNT:
        total_cnt = RAND_COUNT
    nonExisting_cnt = max(0, int(total_cnt - len(data)))
    # Appending zero for those that does not use this feature at all
    # By removing this line you can find the best 
    if include_zero:
        data = data + ([Zero]*nonExisting_cnt)
    return np.sort(data).tolist()

def find_best_fit_for_all_feats(table_name, include_zero=True, useAnderson=False, use_random=True):
    DISTRIBUTIONS = [
        ss.norm, ss.expon, ss.lognorm
    ]
    pval_threshold = 0.05
    cntr = 1
    usr_best_fit = []
    query_time = 0
    fit_time = 0

    # Load DATA from DB
    stime = time.time()
    global group_id_cnt
    #pdb.set_trace()
    group_id_cnt = pd.read_sql('select count(distinct group_id) cnt from ' + table_name, con=engine)
    group_id_cnt = group_id_cnt.cnt[0]
    print(str(group_id_cnt) + ' data points for each feature')
    print(str(RAND_COUNT) + ' random data points will be selected instead, if it is smaller')
    # Load distinct features
    features = pd.read_sql('select feat, count(*) cnt from ' + table_name + ' group by feat', con=engine)
    feat_cnt = len(features)
    print(str(feat_cnt) + ' unique features' )
        
    if include_zero:
        rand_proportion = min(RAND_COUNT/group_id_cnt, 1)
    else:
        rand_proportion = 1
    #pdb.set_trace()
    # Load data feature by feature and find the best distribution for each feature
    for index, eachfeat in features.iterrows():
        feat = eachfeat.feat
        feat = feat.replace("'", "''").replace("%", "%%").replace('\\', '\\\\')
        qs = time.time()
        feat_datapoint_cnt = int(eachfeat.cnt * rand_proportion)
        data = prepare_data(table_name, feat, eachfeat.cnt, feat_datapoint_cnt, include_zero, use_random)
        qe = time.time()
        best_fit_name, max_ll, best_fit_paramms, dist_stat = best_fit_distribution(data)
        usr_best_fit.append([feat, eachfeat.cnt, feat_datapoint_cnt, best_fit_name, max_ll, best_fit_paramms,\
                            dist_stat])
        beste = time.time()
        query_time += (qe-qs)
        fit_time += (beste-qe)
        x = str(cntr) + ' out of ' + str(feat_cnt) + ', ' + feat + '-> query exec: ' \
        + str(round(qe-qs)) + 's, fit: ' + str(round(beste-qe)) + 's'
        print '\r', x, 
        #print x
        cntr += 1
    etime = time.time()
    print
    print('overall time: ' + str(round(etime-stime)) + 's -> query exec: ' + str(round(query_time)) + \
          's , fit: ' + str(round(fit_time)) + 's') 
    df = pd.DataFrame(usr_best_fit, \
                      columns=['feat', 'total_cnt', 'nonzero_cnt', 'best_fitted',  \
                               'best_statistic', 'best_params', 'dist_stat'])
    feat_dist = df.groupby('best_fitted').feat.count()
    print(feat_dist)

    df = df.sort_values('best_statistic')
    return df

# %% [markdown]
# # Draw Two plots for the data
# One including all tested distributions and the other the best fitted one
#
# **Args:**
# * table_name -> to fetch data from
# * feature -> specific feature that we want to fetch data for
#
# **What it does?**
# draws two plots for this data
# * First one contains all the distributions over the histogram of the data with their MLE parameters.
# For this we call function best_fit_distribution with a previously initiated subplot ax with the data ranges.
# * Second one contains the winner, the fitted distribution with minimum SSE among all.
# For this we generate a pdf out of 10000 samples using the parameters of the winning distribution and draw it.

# %%
def draw_plots(data, title, useAnderson=False, plot_pdf=False):
    """Draw plot including real data cdf and also all distributions' cdfs"""
    plt.figure(figsize=(12,8))
    sorted_data = np.sort(data).tolist()
    if plot_pdf:
        plt.hist(sorted_data, bins=200, normed=True, alpha=0.2, color='purple')
    else:
        N = len(sorted_data)
        frequencies = np.arange(1, N+1)/N
        plt.plot(sorted_data, frequencies, color='black', linewidth='3')
        
    ax=plt.subplot(111)
    # Save plot limits
    dataYLim = ax.get_ylim()
    dataXLim = ax.get_xlim()
    
    # Find best fit distribution
    if useAnderson:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = \
        best_anderson_fit_distribution(sorted_data, ax, plot_pdf)
    else:
        best_fit_name, best_sse, best_fit_paramms, dist_stat = best_fit_distribution(sorted_data, ax, plot_pdf)
    ax.legend(loc='upper right')
    best_dist = getattr(ss, best_fit_name)

    # Update plots
    data_array=np.asarray(data)    
    num_of_zeros = len(data_array[data_array==Zero])
    ax.set_ylim(dataYLim)
    ax.set_xlim(dataXLim)
    ax.set_title(str(title) + ',' + best_fit_name + '\n ' + str(num_of_zeros) + '\n All Fitted Distributions')
    ax.set_xlabel('Group Norm')
    ax.set_ylabel('Frequency')
    plt.show()
    plt.close()
    return (best_fit_name, best_sse, best_fit_paramms)

# %% [markdown]
# # Putting all together

# %%
def dist_plus_nBestWorst(table_name, n=4, include_zero=True, plot_cdf=True, plot_pdf=True, anderson=False):
    df = find_best_fit_for_all_feats(table_name, include_zero, anderson)
    print('\n 4 Best Fitted Distributions')
    for idx, eachRow in df.head(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    print('\n 4 Worst Fitted Distributions')
    for idx, eachRow in df.tail(n).iterrows():
        data = prepare_data(table_name, str(eachRow.feat), eachRow.total_cnt, eachRow.nonzero_cnt, include_zero)
        if plot_cdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=False)
        if plot_pdf:
            draw_plots(data, str(eachRow.feat), plot_pdf=True)
    return df

# %% [markdown]
# # LIWC County Level

# %%
df_liwc_wZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$user_id$16to16', plot_cdf=False)
df_liwc_noZero = dist_plus_nBestWorst('feat$cat_LIWC2007$msgs_cnty_r1k$user_id$16to16', include_zero=False)
# Out:
# 10196 data points for each feature
# 10000 random data points will be selected instead, if it is smaller
# 64 unique features
# 64 out of 64, YOU-> query exec: 0.0s, fit: 4.0s
# overall time: 274.0s -> query exec: 5.0s , fit: 269.0s
# best_fitted
# lognorm     25
# powerlaw    39
# Name: feat, dtype: int64
#
#  4 Best Fitted Distributions
#  4 Worst Fitted Distributions
# 10196 data points for each feature
# 10000 random data points will be selected instead, if it is smaller
# 64 unique features
# 64 out of 64, YOU-> query exec: 0.0s, fit: 2.0s
# overall time: 161.0s -> query exec: 6.0s , fit: 155.0s
# best_fitted
# lognorm    64
# Name: feat, dtype: int64
#
#  4 Best Fitted Distributions
#  4 Worst Fitted Distributions

# %% [markdown]
# # Results for LIWC features including zeros

# %%
cntr = 1
for idx, x in df_liwc_wZero.iterrows():
    print cntr,x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[2]) + ", "),
    print    
    print cntr, x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[0]) + ", "),
    print(x.best_fitted)
    print
    cntr+=1
# Out:
# 1 FUNC eFF,  lFF,  pFF,  nTF,
# 1 FUNC e12209.19,  l12529.27,  p-inf,  n8042.11,  lognorm
#
# 2 COGMECH eFF,  lFF,  pFF,  nTF,
# 2 COGMECH e13060.12,  l13717.24,  p-inf,  n8373.7,  lognorm
#
# 3 RELATIV eFF,  lFF,  pFF,  nTF,
# 3 RELATIV e12237.15,  l12657.76,  p19346.12,  n7723.88,  powerlaw
#
# 4 AFFECT eFF,  lFF,  pFF,  nFF,
# 4 AFFECT e13009.86,  l21411.02,  p-inf,  n8014.33,  lognorm
#
# 5 PREP eFF,  lFF,  pFF,  nTF,
# 5 PREP e12309.73,  l12806.74,  p23493.08,  n7697.32,  powerlaw
#
# 6 TENTAT eFF,  lFF,  pFF,  nTF,
# 6 TENTAT e14257.64,  l28988.96,  p-inf,  n8289.07,  lognorm
#
# 7 PPRON eFF,  lFF,  pFF,  nFF,
# 7 PPRON e12873.54,  l29553.12,  p-inf,  n7966.26,  lognorm
#
# 8 TIME eFF,  lFF,  pFF,  nFF,
# 8 TIME e13213.51,  l29262.97,  p31213.67,  n8478.07,  powerlaw
#
# 9 VERBS eFF,  lFF,  pFF,  nFF,
# 9 VERBS e12619.65,  l16120.11,  p31704.34,  n7924.64,  powerlaw
#
# 10 SPACE eFF,  lFF,  pFF,  nTF,
# 10 SPACE e12577.3,  l13170.74,  p31833.08,  n7997.57,  powerlaw
#
# 11 AUXVB eFF,  lFF,  pFF,  nFF,
# 11 AUXVB e12960.09,  l33649.19,  p-inf,  n8104.6,  lognorm
#
# 12 PERCEPT eFF,  lFF,  pFF,  nFF,
# 12 PERCEPT e13850.93,  l34079.84,  p-inf,  n8681.41,  lognorm
#
# 13 PRESENT eFF,  lFF,  pFF,  nFF,
# 13 PRESENT e12812.15,  l34184.72,  p-inf,  n7858.53,  lognorm
#
# 14 PRONOUN eFF,  lFF,  pFF,  nFF,
# 14 PRONOUN e12820.61,  l13525.99,  p34853.85,  n8130.34,  powerlaw
#
# 15 IPRON eFF,  lFF,  pFF,  nFF,
# 15 IPRON e13567.83,  l37312.96,  p28564.11,  n8358.45,  lognorm
#
# 16 SOCIAL eFF,  lFF,  pFF,  nFF,
# 16 SOCIAL e13340.94,  l24950.53,  p39175.87,  n8493.99,  powerlaw
#
# 17 POSEMO eFF,  lFF,  pFF,  nFF,
# 17 POSEMO e12929.87,  l19029.4,  p39845.07,  n7881.08,  powerlaw
#
# 18 LEISURE eFF,  lFF,  pFF,  nFF,
# 18 LEISURE e13693.21,  l21335.9,  p41923.83,  n8694.47,  powerlaw
#
# 19 ARTICLE eFF,  lFF,  pFF,  nFF,
# 19 ARTICLE e13037.83,  l18543.7,  p42825.2,  n8314.06,  powerlaw
#
# 20 ADVERBS eFF,  lFF,  pFF,  nFF,
# 20 ADVERBS e13706.03,  l28773.51,  p49503.96,  n8756.47,  powerlaw
#
# 21 I eFF,  lFF,  pFF,  nFF,
# 21 I e13301.17,  l50833.67,  p34189.36,  n7878.02,  lognorm
#
# 22 INCL eFF,  lFF,  pFF,  nFF,
# 22 INCL e13770.88,  l54234.37,  p45552.52,  n8562.84,  lognorm
#
# 23 WORK eFF,  lFF,  pFF,  nFF,
# 23 WORK e14153.68,  l54531.94,  p39173.62,  n8534.1,  lognorm
#
# 24 CONJ eFF,  lFF,  pFF,  nFF,
# 24 CONJ e13668.56,  l46772.03,  p55614.6,  n8260.03,  powerlaw
#
# 25 MOTION eFF,  lFF,  pFF,  nFF,
# 25 MOTION e14268.63,  l46776.6,  p56879.55,  n8790.91,  powerlaw
#
# 26 CERTAIN eFF,  lFF,  pFF,  nTF,
# 26 CERTAIN e14951.38,  l33546.02,  p58551.58,  n9000.83,  powerlaw
#
# 27 BIO eFF,  lFF,  pFF,  nFF,
# 27 BIO e13658.94,  l58851.45,  p-inf,  n8204.8,  lognorm
#
# 28 CAUSE eFF,  lFF,  pFF,  nTF,
# 28 CAUSE e15041.13,  l59048.33,  p-inf,  n8749.37,  lognorm
#
# 29 SEE eFF,  lFF,  pFF,  nFF,
# 29 SEE e14542.71,  l64206.44,  p63986.73,  n8825.91,  lognorm
#
# 30 ACHIEV eFF,  lFF,  pFF,  nFF,
# 30 ACHIEV e14234.73,  l65505.83,  p-inf,  n8581.79,  lognorm
#
# 31 EXCL eFF,  lFF,  pFF,  nFF,
# 31 EXCL e14147.0,  l67305.4,  p-inf,  n8205.03,  lognorm
#
# 32 BODY eFF,  lFF,  pFF,  nTF,
# 32 BODY e15685.18,  l40830.25,  p72868.04,  n9296.93,  powerlaw
#
# 33 INSIGHT eFF,  lFF,  pFF,  nFF,
# 33 INSIGHT e14827.4,  l75880.5,  p-inf,  n8813.95,  lognorm
#
# 34 HOME eFF,  lFF,  pFF,  nFF,
# 34 HOME e14999.9,  l77236.51,  p59707.54,  n8964.64,  lognorm
#
# 35 NEGATE eFF,  lFF,  pFF,  nTF,
# 35 NEGATE e14724.22,  l37871.21,  p79585.64,  n8872.13,  powerlaw
#
# 36 QUANT eFF,  lFF,  pFF,  nTF,
# 36 QUANT e13984.53,  l25051.23,  p79667.61,  n8352.98,  powerlaw
#
# 37 PAST eFF,  lFF,  pFF,  nFF,
# 37 PAST e14268.72,  l55405.91,  p81287.57,  n8495.35,  powerlaw
#
# 38 INGEST eFF,  lFF,  pFF,  nFF,
# 38 INGEST e14470.03,  l54073.09,  p81521.06,  n8735.12,  powerlaw
#
# 39 NEGEMO eFF,  lFF,  pFF,  nFF,
# 39 NEGEMO e14542.05,  l83790.79,  p83999.52,  n8751.97,  powerlaw
#
# 40 MONEY eFF,  lFF,  pFF,  nFF,
# 40 MONEY e15275.36,  l87279.01,  p-inf,  n9115.86,  lognorm
#
# 41 HEALTH eFF,  lFF,  pFF,  nFF,
# 41 HEALTH e16357.82,  l76158.21,  p87610.61,  n9574.85,  powerlaw
#
# 42 DISCREP eFF,  lFF,  pFF,  nFF,
# 42 DISCREP e15256.7,  l64730.98,  p88506.01,  n8851.06,  powerlaw
#
# 43 ANGER eFF,  lFF,  pFF,  nFF,
# 43 ANGER e16238.45,  l89790.75,  p88795.08,  n9441.67,  lognorm
#
# 44 NUMBERS eFF,  lFF,  pFF,  nFF,
# 44 NUMBERS e15520.93,  l88263.35,  p92433.81,  n9125.34,  powerlaw
#
# 45 RELIG eFF,  lFF,  pFF,  nFF,
# 45 RELIG e16594.61,  l94539.34,  p-inf,  n9732.37,  lognorm
#
# 46 INHIB eFF,  lFF,  pFF,  nFF,
# 46 INHIB e15866.21,  l98383.75,  p-inf,  n9022.82,  lognorm
#
# 47 FILLER eFF,  lFF,  pFF,  nFF,
# 47 FILLER e17773.87,  l90096.24,  p103131.16,  n10422.46,  powerlaw
#
# 48 YOU eFF,  lFF,  pFF,  nFF,
# 48 YOU e15261.19,  l57508.98,  p103886.42,  n9211.03,  powerlaw
#
# 49 WE eFF,  lFF,  pFF,  nFF,
# 49 WE e15854.21,  l106920.31,  p112551.53,  n9499.2,  powerlaw
#
# 50 ASSENT eFF,  lFF,  pFF,  nFF,
# 50 ASSENT e15886.38,  l75108.22,  p112577.01,  n9043.46,  powerlaw
#
# 51 FEEL eFF,  lFF,  pFF,  nFF,
# 51 FEEL e15660.49,  l108201.93,  p113136.56,  n9208.65,  powerlaw
#
# 52 FUTURE eFF,  lFF,  pFF,  nFF,
# 52 FUTURE e15731.82,  l89466.47,  p117645.68,  n8994.36,  powerlaw
#
# 53 HUMANS eFF,  lFF,  pFF,  nFF,
# 53 HUMANS e15365.21,  l109217.23,  p119853.85,  n9091.16,  powerlaw
#
# 54 FRIENDS eFF,  lFF,  pFF,  nTF,
# 54 FRIENDS e17779.77,  l83523.38,  p121707.78,  n10217.62,  powerlaw
#
# 55 HEAR eFF,  lFF,  pFF,  nFF,
# 55 HEAR e16256.8,  l100789.75,  p122933.7,  n9790.45,  powerlaw
#
# 56 ANX eFF,  lFF,  pFF,  nTF,
# 56 ANX e18083.91,  l87933.88,  p124617.69,  n10210.44,  powerlaw
#
# 57 SEXUAL eFF,  lFF,  pFF,  nFF,
# 57 SEXUAL e16090.39,  l111193.51,  p128425.57,  n9162.77,  powerlaw
#
# 58 FAMILY eFF,  lFF,  pFF,  nFF,
# 58 FAMILY e16236.07,  l130609.66,  p130342.49,  n9231.11,  lognorm
#
# 59 THEY eFF,  lFF,  pFF,  nFF,
# 59 THEY e17144.54,  l138061.97,  p-inf,  n9822.33,  lognorm
#
# 60 SAD eFF,  lFF,  pFF,  nFF,
# 60 SAD e17064.38,  l115679.99,  p156030.3,  n9985.29,  powerlaw
#
# 61 SHEHE eFF,  lFF,  pFF,  nFF,
# 61 SHEHE e17284.83,  l115083.95,  p161583.35,  n10263.67,  powerlaw
#
# 62 DEATH eFF,  lFF,  pFF,  nFF,
# 62 DEATH e18813.22,  l121309.12,  p173202.79,  n10568.08,  powerlaw
#
# 63 SWEAR eFF,  lFF,  pFF,  nFF,
# 63 SWEAR e18700.37,  l164005.15,  p176191.35,  n11138.91,  powerlaw
#
# 64 NONFLU eFF,  lFF,  pFF,  nFF,
# 64 NONFLU e19438.63,  l111350.75,  p195654.45,  n10945.03,  powerlaw

# %% [markdown]
# # Result for LIWC features excluding zeros

# %%
cntr = 1
for idx, x in df_liwc_noZero.iterrows():
    print cntr,x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[2]) + ", "),
    print    
    print cntr, x.feat,
    for k, d in x.dist_stat.items():
        print(k[0] + str(d[0]) + ", "),
    print(x.best_fitted)
    print
    cntr+=1
# Out:
# 1 NONFLU eFF,  lFF,  pFF,  nTF,
# 1 NONFLU e2843.86,  l2926.06,  p2419.73,  n1904.82,  lognorm
#
# 2 DEATH eFF,  lFT,  pFF,  nFF,
# 2 DEATH e3180.3,  l3324.67,  p2718.19,  n2026.76,  lognorm
#
# 3 SWEAR eFF,  lFF,  pFF,  nTF,
# 3 SWEAR e-inf,  l3549.77,  p-inf,  n2274.01,  lognorm
#
# 4 ANX eFF,  lFF,  pFF,  nFF,
# 4 ANX e3815.53,  l3917.67,  p3264.01,  n2551.04,  lognorm
#
# 5 FRIENDS eFF,  lFF,  pFF,  nTF,
# 5 FRIENDS e3849.27,  l3979.44,  p3278.12,  n2535.82,  lognorm
#
# 6 THEY eFF,  lFF,  pFF,  nTF,
# 6 THEY e4073.5,  l4238.87,  p-inf,  n2507.38,  lognorm
#
# 7 FILLER eFF,  lFF,  pFF,  nTF,
# 7 FILLER e4370.72,  l4475.85,  p3547.87,  n2937.49,  lognorm
#
# 8 SAD eFF,  lFF,  pFF,  nFF,
# 8 SAD e4465.15,  l4624.97,  p-inf,  n2820.3,  lognorm
#
# 9 SHEHE eFF,  lFF,  pFF,  nTF,
# 9 SHEHE e4664.18,  l4783.66,  p3780.03,  n3071.4,  lognorm
#
# 10 RELIG eFF,  lFF,  pFF,  nTF,
# 10 RELIG e5070.97,  l5184.27,  p4146.12,  n3422.61,  lognorm
#
# 11 ANGER eFF,  lFF,  pFF,  nTF,
# 11 ANGER e-inf,  l5311.5,  p-inf,  n3537.63,  lognorm
#
# 12 FAMILY eFF,  lFF,  pFF,  nTF,
# 12 FAMILY e5155.41,  l5328.11,  p-inf,  n3340.18,  lognorm
#
# 13 SEXUAL eFF,  lFF,  pFF,  nTF,
# 13 SEXUAL e5214.13,  l5353.11,  p4344.76,  n3443.55,  lognorm
#
# 14 HEALTH eFF,  lFF,  pFF,  nFF,
# 14 HEALTH e5305.49,  l5477.7,  p4312.38,  n3395.15,  lognorm
#
# 15 HEAR eFF,  lFF,  pFF,  nTF,
# 15 HEAR e-inf,  l5660.79,  p-inf,  n3822.56,  lognorm
#
# 16 ASSENT eFF,  lFF,  pFF,  nTF,
# 16 ASSENT e5465.18,  l5733.43,  p4645.69,  n3307.77,  lognorm
#
# 17 INHIB eFF,  lFF,  pFF,  nTF,
# 17 INHIB e5642.7,  l5750.5,  p4744.54,  n3900.19,  lognorm
#
# 18 FUTURE eFF,  lFF,  pFF,  nTF,
# 18 FUTURE e5676.36,  l5845.1,  p4834.19,  n3758.59,  lognorm
#
# 19 BODY eFF,  lFF,  pFF,  nTF,
# 19 BODY e5912.35,  l6110.59,  p4798.8,  n3799.32,  lognorm
#
# 20 FEEL eFF,  lFF,  pFF,  nTF,
# 20 FEEL e6005.01,  l6184.73,  p4882.47,  n3948.51,  lognorm
#
# 21 WE eFF,  lFF,  pFF,  nTF,
# 21 WE e6147.75,  l6335.03,  p-inf,  n4094.97,  lognorm
#
# 22 NUMBERS eFF,  lFF,  pFF,  nTF,
# 22 NUMBERS e6283.63,  l6484.42,  p-inf,  n4083.09,  lognorm
#
# 23 HUMANS eFF,  lFF,  pFF,  nTF,
# 23 HUMANS e6352.02,  l6540.96,  p5153.93,  n4146.29,  lognorm
#
# 24 DISCREP eFF,  lFF,  pFF,  nTF,
# 24 DISCREP e-inf,  l6661.8,  p-inf,  n4107.84,  lognorm
#
# 25 MONEY eFF,  lFF,  pFF,  nTF,
# 25 MONEY e6498.65,  l6717.5,  p5403.24,  n4188.61,  lognorm
#
# 26 YOU eFF,  lFF,  pFF,  nFF,
# 26 YOU e6575.6,  l6838.15,  p-inf,  n4148.16,  lognorm
#
# 27 CERTAIN eFF,  lFF,  pFF,  nTF,
# 27 CERTAIN e6784.18,  l7029.17,  p-inf,  n4340.25,  lognorm
#
# 28 HOME eFF,  lFF,  pFF,  nTF,
# 28 HOME e6904.7,  l7057.85,  p5682.87,  n4660.33,  lognorm
#
# 29 CAUSE eFF,  lFF,  pFF,  nTF,
# 29 CAUSE e6879.0,  l7138.53,  p5778.73,  n4452.23,  lognorm
#
# 30 NEGATE eFF,  lFF,  pFF,  nTF,
# 30 NEGATE e7148.84,  l7321.91,  p5866.75,  n4770.5,  lognorm
#
# 31 INSIGHT eFF,  lFF,  pFF,  nTF,
# 31 INSIGHT e7206.09,  l7343.68,  p-inf,  n4891.71,  lognorm
#
# 32 TENTAT eFF,  lFF,  pFF,  nTF,
# 32 TENTAT e7402.71,  l7647.0,  p6068.44,  n4756.71,  lognorm
#
# 33 NEGEMO eFF,  lFF,  pFF,  nTF,
# 33 NEGEMO e7443.43,  l7708.56,  p-inf,  n4747.3,  lognorm
#
# 34 INGEST eFF,  lFF,  pFF,  nTF,
# 34 INGEST e7518.94,  l7788.95,  p6438.91,  n4824.73,  lognorm
#
# 35 SEE eFF,  lFF,  pFF,  nTF,
# 35 SEE e7974.35,  l8261.49,  p6870.15,  n5121.89,  lognorm
#
# 36 EXCL eFF,  lFF,  pFF,  nTF,
# 36 EXCL e8072.56,  l8298.61,  p6592.23,  n5359.75,  lognorm
#
# 37 ACHIEV eFF,  lFF,  pFF,  nTF,
# 37 ACHIEV e8145.91,  l8401.99,  p6823.66,  n5316.51,  lognorm
#
# 38 QUANT eFF,  lFF,  pFF,  nTF,
# 38 QUANT e-inf,  l8445.28,  p-inf,  n5203.41,  lognorm
#
# 39 WORK eFF,  lFF,  pFF,  nTF,
# 39 WORK e8227.23,  l8485.63,  p6916.57,  n5295.65,  lognorm
#
# 40 PAST eFF,  lFF,  pFF,  nTF,
# 40 PAST e8346.49,  l8645.55,  p6792.1,  n5394.52,  lognorm
#
# 41 MOTION eFF,  lFF,  pFF,  nTF,
# 41 MOTION e8453.35,  l8813.34,  p-inf,  n5168.33,  lognorm
#
# 42 PERCEPT eFF,  lFF,  pFF,  nTF,
# 42 PERCEPT e9236.71,  l9541.16,  p-inf,  n6012.09,  lognorm
#
# 43 BIO eFF,  lFF,  pFF,  nTF,
# 43 BIO e9340.56,  l9651.41,  p7865.07,  n6007.88,  lognorm
#
# 44 CONJ eFF,  lFF,  pFF,  nTF,
# 44 CONJ e9374.95,  l9765.37,  p7767.32,  n5871.27,  lognorm
#
# 45 INCL eFF,  lFF,  pFF,  nTF,
# 45 INCL e9496.39,  l9808.65,  p7746.66,  n6194.27,  lognorm
#
# 46 ADVERBS eFF,  lFF,  pFF,  nTF,
# 46 ADVERBS e9595.83,  l9927.99,  p8022.59,  n6247.43,  lognorm
#
# 47 IPRON eFF,  lFF,  pFF,  nTF,
# 47 IPRON e9759.65,  l10104.53,  p7973.89,  n6346.2,  lognorm
#
# 48 LEISURE eFF,  lFF,  pFF,  nTF,
# 48 LEISURE e-inf,  l10213.63,  p-inf,  n6336.81,  lognorm
#
# 49 I eFF,  lFF,  pFF,  nTF,
# 49 I e10361.74,  l10676.87,  p8567.86,  n6894.28,  lognorm
#
# 50 POSEMO eFF,  lFF,  pFF,  nTF,
# 50 POSEMO e10401.07,  l10753.86,  p8760.39,  n6768.97,  lognorm
#
# 51 SOCIAL eFF,  lFF,  pFF,  nTF,
# 51 SOCIAL e10490.79,  l10831.02,  p8553.75,  n6992.47,  lognorm
#
# 52 AUXVB eFF,  lFF,  pFF,  nTF,
# 52 AUXVB e10621.93,  l10975.34,  p8614.77,  n6907.91,  lognorm
#
# 53 AFFECT eFF,  lFF,  pFF,  nTF,
# 53 AFFECT e10711.57,  l11032.42,  p8855.91,  n7036.37,  lognorm
#
# 54 TIME eFF,  lFF,  pFF,  nTF,
# 54 TIME e10740.6,  l11049.04,  p8788.86,  n7059.22,  lognorm
#
# 55 PPRON eFF,  lFF,  pFF,  nTF,
# 55 PPRON e10674.45,  l11054.66,  p9078.94,  n6872.15,  lognorm
#
# 56 ARTICLE eFF,  lFF,  pFF,  nTF,
# 56 ARTICLE e10803.24,  l11079.07,  p8873.29,  n7139.56,  lognorm
#
# 57 PRESENT eFF,  lFF,  pFF,  nTF,
# 57 PRESENT e10677.68,  l11119.38,  p-inf,  n6740.9,  lognorm
#
# 58 COGMECH eFF,  lFF,  pFF,  nTF,
# 58 COGMECH e11133.41,  l11485.85,  p9133.04,  n7241.01,  lognorm
#
# 59 PRONOUN eFF,  lFF,  pFF,  nTF,
# 59 PRONOUN e11211.3,  l11554.01,  p9122.99,  n7393.68,  lognorm
#
# 60 VERBS eFF,  lFF,  pFF,  nTF,
# 60 VERBS e11337.25,  l11728.26,  p9267.28,  n7368.84,  lognorm
#
# 61 SPACE eFF,  lFF,  pFF,  nTF,
# 61 SPACE e11319.75,  l11763.34,  p9585.7,  n7388.18,  lognorm
#
# 62 PREP eFF,  lFF,  pFF,  nTF,
# 62 PREP e11906.2,  l12154.13,  p9806.61,  n8096.4,  lognorm
#
# 63 RELATIV eFF,  lFF,  pFF,  nTF,
# 63 RELATIV e11939.4,  l12351.23,  p-inf,  n7715.2,  lognorm
#
# 64 FUNC eFF,  lFF,  pFF,  nTF,
# 64 FUNC e12294.24,  l12792.7,  p-inf,  n7916.6,  lognorm

# %% [markdown]
# # Choose any feature and see plot for that feature distribution.

# %%
table_name = 'feat$cat_LIWC2007$msgs_cnty_r1k$cnty$16to16'
feat = df_liwc_cnty_wZero[df_liwc_cnty_wZero.feat == 'FILLER'].iloc[0]
data = prepare_data(table_name, str(feat.feat), feat.total_cnt, feat.nonzero_cnt, True)
draw_plots(data, str(feat.feat), plot_pdf=True)
# Out:
# ('lognorm',
#  1343.7106962085195,
#  (0.69181032406454368, -0.00015058627147508229, 0.0022629401460301838))
